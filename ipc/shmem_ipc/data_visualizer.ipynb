# %%
import pandas as pd
import matplotlib.pyplot as mp
import os

RECORDED_APPROACHES = []

def extract_time_data(filename: str):
    with open(filename, 'r') as f:
        data = f.read().splitlines()
        time_data = []
        iteration_indices = []

        iteration_idx = 1
        for entry in data:
            elems = entry.split()
            if (len(elems) < 2) or (elems[0] != 'Time'):
                continue

            time_data.append(elems[2])
            iteration_indices.append(iteration_idx)

            iteration_idx += 1

        return (iteration_indices, time_data)
    
def create_csv(data_dir: str) -> None:
    all_time_data = {}
    
    if os.path.isfile('{}/approach1_log.txt'.format(data_dir)):
        all_time_data['Independent Client'] = extract_time_data('{}/approach1_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client')
    
    if os.path.isfile('{}/approach2_log.txt'.format(data_dir)):
        all_time_data['Independent Client Elevated'] = extract_time_data('{}/approach2_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client Elevated')
        
    if os.path.isfile('{}/approach3_log.txt'.format(data_dir)):
        all_time_data['Client + Server'] = extract_time_data('{}/approach3_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server')
        
    if os.path.isfile('{}/approach4_log.txt'.format(data_dir)):
        all_time_data['Client + Server Elevated'] = extract_time_data('{}/approach4_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server Elevated')
        
    with open('{}/results.csv'.format(data_dir), 'w') as f:
        f.write('Iteration,')
        f.write(','.join(all_time_data.keys()))
        f.write('\n')
        
        iterations = list(all_time_data.values())[0][0]
        for i in iterations:
            f.write(str(i))
            f.write(',')
            
            for j in range(len(all_time_data)):
                approach = list(all_time_data.keys())[j]
                approach_data = all_time_data[approach]
                time_data = approach_data[1]
                f.write(str(time_data[i - 1]))
                if j == (len(all_time_data) - 1):
                    f.write('\n')
                else:
                    f.write(',')

        
data_dir = input('Enter the data directory: ')
create_csv(data_dir)
csv_data = pd.read_csv('{}/results.csv'.format(data_dir))

# Form dataframe from data
columns = ['Iteration']
for a in RECORDED_APPROACHES:
    columns.append(a)

df = pd.DataFrame(csv_data, columns=columns)

# Plot multiple columns such as population and year from dataframe
df.plot(x='Iteration', y=RECORDED_APPROACHES, kind="line", figsize=(10, 10))

# Display plot
mp.show()
# Out:
# Enter the data directory: ./trend_data/2k

# %%
import pandas as pd
import matplotlib.pyplot as mp
import os

RECORDED_APPROACHES = []

def extract_time_data(filename: str):
    with open(filename, 'r') as f:
        data = f.read().splitlines()
        time_data = []
        iteration_indices = []

        iteration_idx = 1
        for entry in data:
            elems = entry.split()
            if (len(elems) < 2) or (elems[0] != 'Time'):
                continue

            time_data.append(elems[2])
            iteration_indices.append(iteration_idx)

            iteration_idx += 1

        return (iteration_indices, time_data)
    
def create_csv(data_dir: str) -> None:
    all_time_data = {}
    
    if os.path.isfile('{}/approach1_log.txt'.format(data_dir)):
        all_time_data['Independent Client'] = extract_time_data('{}/approach1_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client')
    
    if os.path.isfile('{}/approach2_log.txt'.format(data_dir)):
        all_time_data['Independent Client Elevated'] = extract_time_data('{}/approach2_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client Elevated')
        
    if os.path.isfile('{}/approach3_log.txt'.format(data_dir)):
        all_time_data['Client + Server'] = extract_time_data('{}/approach3_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server')
        
    if os.path.isfile('{}/approach4_log.txt'.format(data_dir)):
        all_time_data['Client + Server Elevated'] = extract_time_data('{}/approach4_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server Elevated')
        
    with open('{}/results.csv'.format(data_dir), 'w') as f:
        f.write('Iteration,')
        f.write(','.join(all_time_data.keys()))
        f.write('\n')
        
        iterations = list(all_time_data.values())[0][0]
        for i in iterations:
            f.write(str(i))
            f.write(',')
            
            for j in range(len(all_time_data)):
                approach = list(all_time_data.keys())[j]
                approach_data = all_time_data[approach]
                time_data = approach_data[1]
                f.write(str(time_data[i - 1]))
                if j == (len(all_time_data) - 1):
                    f.write('\n')
                else:
                    f.write(',')

        
data_dir = input('Enter the data directory: ')
create_csv(data_dir)
csv_data = pd.read_csv('{}/results.csv'.format(data_dir))

# Form dataframe from data
columns = ['Iteration']
for a in RECORDED_APPROACHES:
    columns.append(a)

df = pd.DataFrame(csv_data, columns=columns)

# Plot multiple columns such as population and year from dataframe
df.plot(x='Iteration', y=RECORDED_APPROACHES, kind="line", figsize=(10, 10))

# Display plot
mp.show()
# Out:
# Enter the data directory: ./trend_data/4k

# %%
import pandas as pd
import matplotlib.pyplot as mp
import os

RECORDED_APPROACHES = []

def extract_time_data(filename: str):
    with open(filename, 'r') as f:
        data = f.read().splitlines()
        time_data = []
        iteration_indices = []

        iteration_idx = 1
        for entry in data:
            elems = entry.split()
            if (len(elems) < 2) or (elems[0] != 'Time'):
                continue

            time_data.append(elems[2])
            iteration_indices.append(iteration_idx)

            iteration_idx += 1

        return (iteration_indices, time_data)
    
def create_csv(data_dir: str) -> None:
    all_time_data = {}
    
    if os.path.isfile('{}/approach1_log.txt'.format(data_dir)):
        all_time_data['Independent Client'] = extract_time_data('{}/approach1_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client')
    
    if os.path.isfile('{}/approach2_log.txt'.format(data_dir)):
        all_time_data['Independent Client Elevated'] = extract_time_data('{}/approach2_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client Elevated')
        
    if os.path.isfile('{}/approach3_log.txt'.format(data_dir)):
        all_time_data['Client + Server'] = extract_time_data('{}/approach3_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server')
        
    if os.path.isfile('{}/approach4_log.txt'.format(data_dir)):
        all_time_data['Client + Server Elevated'] = extract_time_data('{}/approach4_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server Elevated')
        
    with open('{}/results.csv'.format(data_dir), 'w') as f:
        f.write('Iteration,')
        f.write(','.join(all_time_data.keys()))
        f.write('\n')
        
        iterations = list(all_time_data.values())[0][0]
        for i in iterations:
            f.write(str(i))
            f.write(',')
            
            for j in range(len(all_time_data)):
                approach = list(all_time_data.keys())[j]
                approach_data = all_time_data[approach]
                time_data = approach_data[1]
                f.write(str(time_data[i - 1]))
                if j == (len(all_time_data) - 1):
                    f.write('\n')
                else:
                    f.write(',')

        
data_dir = input('Enter the data directory: ')
create_csv(data_dir)
csv_data = pd.read_csv('{}/results.csv'.format(data_dir))

# Form dataframe from data
columns = ['Iteration']
for a in RECORDED_APPROACHES:
    columns.append(a)

df = pd.DataFrame(csv_data, columns=columns)

# Plot multiple columns such as population and year from dataframe
df.plot(x='Iteration', y=RECORDED_APPROACHES, kind="line", figsize=(10, 10))

# Display plot
mp.show()
# Out:
# Enter the data directory: ./trend_data/8k

# %%
import pandas as pd
import matplotlib.pyplot as mp
import os

RECORDED_APPROACHES = []

def extract_time_data(filename: str):
    with open(filename, 'r') as f:
        data = f.read().splitlines()
        time_data = []
        iteration_indices = []

        iteration_idx = 1
        for entry in data:
            elems = entry.split()
            if (len(elems) < 2) or (elems[0] != 'Time'):
                continue

            time_data.append(elems[2])
            iteration_indices.append(iteration_idx)

            iteration_idx += 1

        return (iteration_indices, time_data)
    
def create_csv(data_dir: str) -> None:
    all_time_data = {}
    
    if os.path.isfile('{}/approach1_log.txt'.format(data_dir)):
        all_time_data['Independent Client'] = extract_time_data('{}/approach1_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client')
    
    if os.path.isfile('{}/approach2_log.txt'.format(data_dir)):
        all_time_data['Independent Client Elevated'] = extract_time_data('{}/approach2_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client Elevated')
        
    if os.path.isfile('{}/approach3_log.txt'.format(data_dir)):
        all_time_data['Client + Server'] = extract_time_data('{}/approach3_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server')
        
    if os.path.isfile('{}/approach4_log.txt'.format(data_dir)):
        all_time_data['Client + Server Elevated'] = extract_time_data('{}/approach4_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server Elevated')
        
    with open('{}/results.csv'.format(data_dir), 'w') as f:
        f.write('Iteration,')
        f.write(','.join(all_time_data.keys()))
        f.write('\n')
        
        iterations = list(all_time_data.values())[0][0]
        for i in iterations:
            f.write(str(i))
            f.write(',')
            
            for j in range(len(all_time_data)):
                approach = list(all_time_data.keys())[j]
                approach_data = all_time_data[approach]
                time_data = approach_data[1]
                f.write(str(time_data[i - 1]))
                if j == (len(all_time_data) - 1):
                    f.write('\n')
                else:
                    f.write(',')

        
data_dir = input('Enter the data directory: ')
create_csv(data_dir)
csv_data = pd.read_csv('{}/results.csv'.format(data_dir))

# Form dataframe from data
columns = ['Iteration']
for a in RECORDED_APPROACHES:
    columns.append(a)

df = pd.DataFrame(csv_data, columns=columns)

# Plot multiple columns such as population and year from dataframe
df.plot(x='Iteration', y=RECORDED_APPROACHES, kind="line", figsize=(10, 10))

# Display plot
mp.show()
# Out:
# Enter the data directory: ./trend_data/15k

# %%
import pandas as pd
import matplotlib.pyplot as mp
import os

RECORDED_APPROACHES = []

def extract_time_data(filename: str):
    with open(filename, 'r') as f:
        data = f.read().splitlines()
        time_data = []
        iteration_indices = []

        iteration_idx = 1
        for entry in data:
            elems = entry.split()
            if (len(elems) < 2) or (elems[0] != 'Time'):
                continue

            time_data.append(elems[2])
            iteration_indices.append(iteration_idx)

            iteration_idx += 1

        return (iteration_indices, time_data)
    
def create_csv(data_dir: str) -> None:
    all_time_data = {}
    
    if os.path.isfile('{}/approach1_log.txt'.format(data_dir)):
        all_time_data['Independent Client'] = extract_time_data('{}/approach1_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client')
    
    if os.path.isfile('{}/approach2_log.txt'.format(data_dir)):
        all_time_data['Independent Client Elevated'] = extract_time_data('{}/approach2_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client Elevated')
        
    if os.path.isfile('{}/approach3_log.txt'.format(data_dir)):
        all_time_data['Client + Server'] = extract_time_data('{}/approach3_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server')
        
    if os.path.isfile('{}/approach4_log.txt'.format(data_dir)):
        all_time_data['Client + Server Elevated'] = extract_time_data('{}/approach4_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server Elevated')
        
    with open('{}/results.csv'.format(data_dir), 'w') as f:
        f.write('Iteration,')
        f.write(','.join(all_time_data.keys()))
        f.write('\n')
        
        iterations = list(all_time_data.values())[0][0]
        for i in iterations:
            f.write(str(i))
            f.write(',')
            
            for j in range(len(all_time_data)):
                approach = list(all_time_data.keys())[j]
                approach_data = all_time_data[approach]
                time_data = approach_data[1]
                f.write(str(time_data[i - 1]))
                if j == (len(all_time_data) - 1):
                    f.write('\n')
                else:
                    f.write(',')

        
data_dir = input('Enter the data directory: ')
create_csv(data_dir)
csv_data = pd.read_csv('{}/results.csv'.format(data_dir))

# Form dataframe from data
columns = ['Iteration']
for a in RECORDED_APPROACHES:
    columns.append(a)

df = pd.DataFrame(csv_data, columns=columns)

# Plot multiple columns such as population and year from dataframe
df.plot(x='Iteration', y=RECORDED_APPROACHES, kind="line", figsize=(10, 10))

# Display plot
mp.show()
# Out:
# Enter the data directory: ./trend_data/20k

# %%
import pandas as pd
import matplotlib.pyplot as mp
import os

RECORDED_APPROACHES = []

def extract_time_data(filename: str):
    with open(filename, 'r') as f:
        data = f.read().splitlines()
        time_data = []
        iteration_indices = []

        iteration_idx = 1
        for entry in data:
            elems = entry.split()
            if (len(elems) < 2) or (elems[0] != 'Time'):
                continue

            time_data.append(elems[2])
            iteration_indices.append(iteration_idx)

            iteration_idx += 1

        return (iteration_indices, time_data)
    
def create_csv(data_dir: str) -> None:
    all_time_data = {}
    
    if os.path.isfile('{}/approach1_log.txt'.format(data_dir)):
        all_time_data['Independent Client'] = extract_time_data('{}/approach1_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client')
    
    if os.path.isfile('{}/approach2_log.txt'.format(data_dir)):
        all_time_data['Independent Client Elevated'] = extract_time_data('{}/approach2_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client Elevated')
        
    if os.path.isfile('{}/approach3_log.txt'.format(data_dir)):
        all_time_data['Client + Server'] = extract_time_data('{}/approach3_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server')
        
    if os.path.isfile('{}/approach4_log.txt'.format(data_dir)):
        all_time_data['Client + Server Elevated'] = extract_time_data('{}/approach4_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server Elevated')
        
    with open('{}/results.csv'.format(data_dir), 'w') as f:
        f.write('Iteration,')
        f.write(','.join(all_time_data.keys()))
        f.write('\n')
        
        iterations = list(all_time_data.values())[0][0]
        for i in iterations:
            f.write(str(i))
            f.write(',')
            
            for j in range(len(all_time_data)):
                approach = list(all_time_data.keys())[j]
                approach_data = all_time_data[approach]
                time_data = approach_data[1]
                f.write(str(time_data[i - 1]))
                if j == (len(all_time_data) - 1):
                    f.write('\n')
                else:
                    f.write(',')

        
data_dir = input('Enter the data directory: ')
create_csv(data_dir)
csv_data = pd.read_csv('{}/results.csv'.format(data_dir))

# Form dataframe from data
columns = ['Iteration']
for a in RECORDED_APPROACHES:
    columns.append(a)

df = pd.DataFrame(csv_data, columns=columns)

# Plot multiple columns such as population and year from dataframe
df.plot(x='Iteration', y=RECORDED_APPROACHES, kind="line", figsize=(10, 10))

# Display plot
mp.show()
# Out:
# Enter the data directory: ./trend_data/30k

# %%
import pandas as pd
import matplotlib.pyplot as mp
import os

RECORDED_APPROACHES = []

def extract_time_data(filename: str):
    with open(filename, 'r') as f:
        data = f.read().splitlines()
        time_data = []
        iteration_indices = []

        iteration_idx = 1
        for entry in data:
            elems = entry.split()
            if (len(elems) < 2) or (elems[0] != 'Time'):
                continue

            time_data.append(elems[2])
            iteration_indices.append(iteration_idx)

            iteration_idx += 1

        return (iteration_indices, time_data)
    
def create_csv(data_dir: str) -> None:
    all_time_data = {}
    
    if os.path.isfile('{}/approach1_log.txt'.format(data_dir)):
        all_time_data['Independent Client'] = extract_time_data('{}/approach1_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client')
    
    if os.path.isfile('{}/approach2_log.txt'.format(data_dir)):
        all_time_data['Independent Client Elevated'] = extract_time_data('{}/approach2_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client Elevated')
        
    if os.path.isfile('{}/approach3_log.txt'.format(data_dir)):
        all_time_data['Client + Server'] = extract_time_data('{}/approach3_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server')
        
    if os.path.isfile('{}/approach4_log.txt'.format(data_dir)):
        all_time_data['Client + Server Elevated'] = extract_time_data('{}/approach4_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server Elevated')
        
    with open('{}/results.csv'.format(data_dir), 'w') as f:
        f.write('Iteration,')
        f.write(','.join(all_time_data.keys()))
        f.write('\n')
        
        iterations = list(all_time_data.values())[0][0]
        for i in iterations:
            f.write(str(i))
            f.write(',')
            
            for j in range(len(all_time_data)):
                approach = list(all_time_data.keys())[j]
                approach_data = all_time_data[approach]
                time_data = approach_data[1]
                f.write(str(time_data[i - 1]))
                if j == (len(all_time_data) - 1):
                    f.write('\n')
                else:
                    f.write(',')

        
data_dir = input('Enter the data directory: ')
create_csv(data_dir)
csv_data = pd.read_csv('{}/results.csv'.format(data_dir))

# Form dataframe from data
columns = ['Iteration']
for a in RECORDED_APPROACHES:
    columns.append(a)

df = pd.DataFrame(csv_data, columns=columns)

# Plot multiple columns such as population and year from dataframe
df.plot(x='Iteration', y=RECORDED_APPROACHES, kind="line", figsize=(10, 10))

# Display plot
mp.show()
# Out:
# Enter the data directory: ./trend_data/40k

# %%
import pandas as pd
import matplotlib.pyplot as mp
import os

RECORDED_APPROACHES = []

def extract_time_data(filename: str):
    with open(filename, 'r') as f:
        data = f.read().splitlines()
        time_data = []
        iteration_indices = []

        iteration_idx = 1
        for entry in data:
            elems = entry.split()
            if (len(elems) < 2) or (elems[0] != 'Time'):
                continue

            time_data.append(elems[2])
            iteration_indices.append(iteration_idx)

            iteration_idx += 1

        return (iteration_indices, time_data)
    
def create_csv(data_dir: str) -> None:
    all_time_data = {}
    
    if os.path.isfile('{}/approach1_log.txt'.format(data_dir)):
        all_time_data['Independent Client'] = extract_time_data('{}/approach1_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client')
    
    if os.path.isfile('{}/approach2_log.txt'.format(data_dir)):
        all_time_data['Independent Client Elevated'] = extract_time_data('{}/approach2_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client Elevated')
        
    if os.path.isfile('{}/approach3_log.txt'.format(data_dir)):
        all_time_data['Client + Server'] = extract_time_data('{}/approach3_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server')
        
    if os.path.isfile('{}/approach4_log.txt'.format(data_dir)):
        all_time_data['Client + Server Elevated'] = extract_time_data('{}/approach4_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server Elevated')
        
    with open('{}/results.csv'.format(data_dir), 'w') as f:
        f.write('Iteration,')
        f.write(','.join(all_time_data.keys()))
        f.write('\n')
        
        iterations = list(all_time_data.values())[0][0]
        for i in iterations:
            f.write(str(i))
            f.write(',')
            
            for j in range(len(all_time_data)):
                approach = list(all_time_data.keys())[j]
                approach_data = all_time_data[approach]
                time_data = approach_data[1]
                f.write(str(time_data[i - 1]))
                if j == (len(all_time_data) - 1):
                    f.write('\n')
                else:
                    f.write(',')

        
data_dir = input('Enter the data directory: ')
create_csv(data_dir)
csv_data = pd.read_csv('{}/results.csv'.format(data_dir))

# Form dataframe from data
columns = ['Iteration']
for a in RECORDED_APPROACHES:
    columns.append(a)

df = pd.DataFrame(csv_data, columns=columns)

# Plot multiple columns such as population and year from dataframe
df.plot(x='Iteration', y=RECORDED_APPROACHES, kind="line", figsize=(10, 10))

# Display plot
mp.show()
# Out:
# Enter the data directory: trend_data/50k

# %%
import pandas as pd
import matplotlib.pyplot as mp
import os

RECORDED_APPROACHES = []

def extract_time_data(filename: str):
    with open(filename, 'r') as f:
        data = f.read().splitlines()
        time_data = []
        iteration_indices = []

        iteration_idx = 1
        for entry in data:
            elems = entry.split()
            if (len(elems) < 2) or (elems[0] != 'Time'):
                continue

            time_data.append(elems[2])
            iteration_indices.append(iteration_idx)

            iteration_idx += 1

        return (iteration_indices, time_data)
    
def create_csv(data_dir: str) -> None:
    all_time_data = {}
    
    if os.path.isfile('{}/approach1_log.txt'.format(data_dir)):
        all_time_data['Independent Client'] = extract_time_data('{}/approach1_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client')
    
    if os.path.isfile('{}/approach2_log.txt'.format(data_dir)):
        all_time_data['Independent Client Elevated'] = extract_time_data('{}/approach2_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Independent Client Elevated')
        
    if os.path.isfile('{}/approach3_log.txt'.format(data_dir)):
        all_time_data['Client + Server'] = extract_time_data('{}/approach3_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server')
        
    if os.path.isfile('{}/approach4_log.txt'.format(data_dir)):
        all_time_data['Client + Server Elevated'] = extract_time_data('{}/approach4_log.txt'.format(data_dir))
        RECORDED_APPROACHES.append('Client + Server Elevated')
        
    with open('{}/results.csv'.format(data_dir), 'w') as f:
        f.write('Iteration,')
        f.write(','.join(all_time_data.keys()))
        f.write('\n')
        
        iterations = list(all_time_data.values())[0][0]
        for i in iterations:
            f.write(str(i))
            f.write(',')
            
            for j in range(len(all_time_data)):
                approach = list(all_time_data.keys())[j]
                approach_data = all_time_data[approach]
                time_data = approach_data[1]
                f.write(str(time_data[i - 1]))
                if j == (len(all_time_data) - 1):
                    f.write('\n')
                else:
                    f.write(',')

        
data_dir = input('Enter the data directory: ')
create_csv(data_dir)
csv_data = pd.read_csv('{}/results.csv'.format(data_dir))

# Form dataframe from data
columns = ['Iteration']
for a in RECORDED_APPROACHES:
    columns.append(a)

df = pd.DataFrame(csv_data, columns=columns)

# Plot multiple columns such as population and year from dataframe
df.plot(x='Iteration', y=RECORDED_APPROACHES, kind="line", figsize=(10, 10))

# Display plot
mp.show()
# Out:
# Enter the data directory: ./trend_data/combined
