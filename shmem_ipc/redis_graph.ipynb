# %%
import pandas as pd
import seaborn as sb

sb.set_theme(style="darkgrid")
sb.color_palette("Set2")
sb.set(rc={'figure.figsize':(9.7,6.27)})

def preprocess_data(data: pd.DataFrame):
    base_tp_val = 0
    for i in range(len(data['redis_instances'])):
        if i == 0:
            base_tp_val = float(data['throughput'][i])
        
        data['throughput'][i] /= base_tp_val

df = pd.read_csv("redis_results.csv")
preprocess_data(df)

g = sb.barplot(data=df, x='redis_instances', y='throughput', hue='type')
#g.set_xticks(range(len(df)))
g.set_yticks(range(0, 15))
# Out:
# /var/folders/4_/626_qvf53hn3c5yvb9qh47yh0000gn/T/ipykernel_23196/3079034629.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['throughput'][i] /= base_tp_val
# [<matplotlib.axis.YTick at 0x168c7ed30>,
#  <matplotlib.axis.YTick at 0x168c7e6d0>,
#  <matplotlib.axis.YTick at 0x168c75f40>,
#  <matplotlib.axis.YTick at 0x168874490>,
#  <matplotlib.axis.YTick at 0x168c65fd0>,
#  <matplotlib.axis.YTick at 0x168d0d250>,
#  <matplotlib.axis.YTick at 0x168c5ef10>,
#  <matplotlib.axis.YTick at 0x168d0db50>,
#  <matplotlib.axis.YTick at 0x168d17640>,
#  <matplotlib.axis.YTick at 0x168d17d90>,
#  <matplotlib.axis.YTick at 0x168d17c40>,
#  <matplotlib.axis.YTick at 0x168d0d700>,
#  <matplotlib.axis.YTick at 0x168d20490>,
#  <matplotlib.axis.YTick at 0x168d20f40>,
#  <matplotlib.axis.YTick at 0x168d26a30>]
